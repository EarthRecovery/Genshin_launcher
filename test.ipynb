# %%
import requests

# 替换成你的 API URL
api_url = 'https://enka.network/api/uid/618285856'

try:
    response = requests.get(api_url)

    if response.status_code == 200:
        data = response.json()  # 将响应的 JSON 数据解析为 Python 字典或列表
        print(data)
    else:
        print('Request failed with status code:', response.status_code)

except requests.exceptions.RequestException as e:
    print('Error fetching data:', e)
# Out:
# {'playerInfo': {'nickname': 'Algoinde', 'level': 57, 'signature': 'Meta rejected us. So we rejected the meta.', 'worldLevel': 8, 'nameCardId': 210001, 'finishAchievementNum': 439, 'towerFloorIndex': 8, 'towerLevelIndex': 3, 'showAvatarInfoList': [{'avatarId': 10000021, 'level': 90}, {'avatarId': 10000032, 'level': 90}, {'avatarId': 10000037, 'level': 90}, {'avatarId': 10000025, 'level': 80}], 'showNameCardIdList': [210051, 210087, 210018, 210013, 210003, 210006, 210115, 210084, 210053], 'profilePicture': {'avatarId': 10000021}}, 'avatarInfoList': [{'avatarId': 10000021, 'propMap': {'1001': {'type': 1001, 'ival': '0'}, '1002': {'type': 1002, 'ival': '6', 'val': '6'}, '1003': {'type': 1003, 'ival': '0'}, '1004': {'type': 1004, 'ival': '0'}, '4001': {'type': 4001, 'ival': '90', 'val': '90'}, '10010': {'type': 10010, 'ival': '24000', 'val': '24000'}}, 'talentIdList': [211, 212, 213, 214, 215, 216], 'fightPropMap': {'1': 9461.17578125, '2': 4780, '4': 897.3515625, '5': 381.0299987792969, '6': 1.2131999731063843, '7': 600.6189575195312, '8': 97.22999572753906, '9': 0.4226999878883362, '20': 0.5194119811058044, '21': 0, '22': 1.88919997215271, '23': 1, '25': 0, '26': 0, '27': 0, '28': 39.62999725341797, '29': 0, '30': 1.0829999446868896, '40': 0, '41': 0, '42': 0, '43': 0, '44': 0, '45': 0, '46': 0, '50': 0, '51': 0, '52': 0, '53': 0, '54': 0, '55': 0, '56': 0, '70': 40, '1000': 27.600006103515625, '1010': 12231.25390625, '2000': 14241.17578125, '2001': 2367.048583984375, '2002': 951.7305297851562, '2003': 0, '3008': 0, '3014': 0, '3045': 0, '3046': 1}, 'skillDepotId': 2101, 'inherentProudSkillList': [212101, 212201, 212301], 'skillLevelMap': {'10017': 10, '10032': 10, '10041': 10}, 'proudSkillExtraLevelMap': {'2132': 3, '2139': 3}, 'equipList': [{'itemId': 82543, 'reliquary': {'level': 21, 'mainPropId': 14001, 'appendPropIdList': [501082, 501063, 501221, 501242, 501222, 501082, 501223, 501064]}, 'flat': {'nameTextMapHash': '513291572', 'setNameTextMapHash': '1541919827', 'rankLevel': 5, 'reliquaryMainstat': {'mainPropId': 'FIGHT_PROP_HP', 'statValue': 4780}, 'reliquarySubstats': [{'appendPropId': 'FIGHT_PROP_DEFENSE', 'statValue': 37}, {'appendPropId': 'FIGHT_PROP_ATTACK_PERCENT', 'statValue': 11.1}, {'appendPropId': 'FIGHT_PROP_CRITICAL_HURT', 'statValue': 18.7}, {'appendPropId': 'FIGHT_PROP_ELEMENT_MASTERY', 'statValue': 19}], 'itemType': 'ITEM_RELIQUARY', 'icon': 'UI_RelicIcon_15008_4', 'equipType': 'EQUIP_BRACER'}}, {'itemId': 82524, 'reliquary': {'level': 21, 'mainPropId': 12001, 'appendPropIdList': [501204, 501061, 501093, 501224, 501094, 501223, 501091, 501064, 501224]}, 'flat': {'nameTextMapHash': '3671975700', 'setNameTextMapHash': '1541919827', 'rankLevel': 5, 'reliquaryMainstat': {'mainPropId': 'FIGHT_PROP_ATTACK', 'statValue': 311}, 'reliquarySubstats': [{'appendPropId': 'FIGHT_PROP_CRITICAL', 'statValue': 3.9}, {'appendPropId': 'FIGHT_PROP_ATTACK_PERCENT', 'statValue': 9.9}, {'appendPropId': 'FIGHT_PROP_DEFENSE_PERCENT', 'statValue': 19}, {'appendPropId': 'FIGHT_PROP_CRITICAL_HURT', 'statValue': 22.5}], 'itemType': 'ITEM_RELIQUARY', 'icon': 'UI_RelicIcon_15008_2', 'equipType': 'EQUIP_NECKLACE'}}, {'itemId': 81553, 'reliquary': {'level': 21, 'mainPropId': 10004, 'appendPropIdList': [501243, 501051, 501204, 501224, 501204, 501201, 501204, 501224]}, 'flat': {'nameTextMapHash': '514109556', 'setNameTextMapHash': '1751039235', 'rankLevel': 5, 'reliquaryMainstat': {'mainPropId': 'FIGHT_PROP_ATTACK_PERCENT', 'statValue': 46.6}, 'reliquarySubstats': [{'appendPropId': 'FIGHT_PROP_ELEMENT_MASTERY', 'statValue': 21}, {'appendPropId': 'FIGHT_PROP_ATTACK', 'statValue': 14}, {'appendPropId': 'FIGHT_PROP_CRITICAL', 'statValue': 14.4}, {'appendPropId': 'FIGHT_PROP_CRITICAL_HURT', 'statValue': 15.5}], 'itemType': 'ITEM_RELIQUARY', 'icon': 'UI_RelicIcon_15007_5', 'equipType': 'EQUIP_SHOES'}}, {'itemId': 92514, 'reliquary': {'level': 21, 'mainPropId': 15015, 'appendPropIdList': [501203, 501054, 501062, 501091, 501053, 501062, 501202, 5010 ...
